# %%
import pandas as pd
import numpy as np
import ast
import os

# %%
# Paths (change if your folder names differ)
raw_battles_path = r"C:\DSC106\project4\CR_data\BattlesStaging_small.csv"
card_master_path = r"C:\DSC106\project4\CR_data\CardMasterListSeason18_12082020_with_elixir_and_rarity.csv"

# Output file for the new dataset
output_path = r"C:\DSC106\project4\CR_data\BattlesStaging_with_card_features.csv"

# %% [markdown]
# Load card metadata and build lookup dictionaries

# %%
# Read the card metadata (with type, elixir, rarity)
cards_meta = pd.read_csv(card_master_path)

# Use card ID as index so we can look things up quickly
cards_meta = cards_meta.set_index("team.card1.id")

# Build dictionaries: card ID -> attribute
id_to_name   = cards_meta["team.card1.name"].to_dict()
id_to_type   = cards_meta["card_type"].to_dict()   # column is "card_type" in this file
id_to_elixir = cards_meta["elixir"].to_dict()
id_to_rarity = cards_meta["rarity"].to_dict()

# Quick sanity check
list(id_to_name.items())[:5]
# Out:
# [(26000000, 'Knight'),
#  (26000001, 'Archers'),
#  (26000002, 'Goblins'),
#  (26000003, 'Giant'),
#  (26000004, 'P.E.K.K.A')]

# %% [markdown]
# Helper function to expand one side (winner/loser)

# %%
def add_card_features(df_chunk, side, list_col):
    """
    side: "winner" or "loser"
    list_col: column name with the list of card IDs
              e.g. "winner.cards.list" or "loser.cards.list"
    """
    def parse_list(x):
        # x is a string like "[26000036, 26000043, ...]"
        if isinstance(x, str) and x.strip():
            try:
                lst = ast.literal_eval(x)
                # Make sure length is exactly 8
                if len(lst) < 8:
                    lst = lst + [np.nan] * (8 - len(lst))
                elif len(lst) > 8:
                    lst = lst[:8]
                return lst
            except Exception:
                return [np.nan] * 8
        else:
            return [np.nan] * 8

    # Turn the list column into 8 separate columns of card IDs
    ids_df = df_chunk[list_col].apply(parse_list).apply(pd.Series)

    # For slot 1..8, map ID to name/type/elixir/rarity
    for i in range(8):
        card_ids = ids_df[i]
        df_chunk[f"{side}_card_{i+1}_name"]   = card_ids.map(id_to_name)
        df_chunk[f"{side}_card_{i+1}_type"]   = card_ids.map(id_to_type)
        df_chunk[f"{side}_card_{i+1}_elixir"] = card_ids.map(id_to_elixir)
        df_chunk[f"{side}_card_{i+1}_rarity"] = card_ids.map(id_to_rarity)

    return df_chunk

# %% [markdown]
# Load raw battles, add winner + loser features, reorder columns, save

# %%
# Read the raw dataset with winner + loser card lists
battles = pd.read_csv(raw_battles_path)

print("Raw shape:", battles.shape)
print(battles.head())

# Add winner card features
battles = add_card_features(battles, side="winner", list_col="winner.cards.list")

# Add loser card features
battles = add_card_features(battles, side="loser", list_col="loser.cards.list")

# ----- Reorder columns -----

# Keep the original four columns first
base_cols = [
    "battleTime",
    "average.startingTrophies",
    "winner.cards.list",
    "loser.cards.list",
]

# Then winner_card_1_name, winner_card_1_type, winner_card_1_elixir, winner_card_1_rarity, ...
winner_cols = []
for i in range(1, 9):
    winner_cols.extend([
        f"winner_card_{i}_name",
        f"winner_card_{i}_type",
        f"winner_card_{i}_elixir",
        f"winner_card_{i}_rarity",
    ])

# Then loser_card_1_name, loser_card_1_type, loser_card_1_elixir, loser_card_1_rarity, ...
loser_cols = []
for i in range(1, 9):
    loser_cols.extend([
        f"loser_card_{i}_name",
        f"loser_card_{i}_type",
        f"loser_card_{i}_elixir",
        f"loser_card_{i}_rarity",
    ])

new_order = base_cols + winner_cols + loser_cols

# Select columns in this exact order
battles_final = battles[new_order]

print("Final shape:", battles_final.shape)
battles_final.head()
# Out:
# Raw shape: (37973387, 4)
#                   battleTime  average.startingTrophies  \
# 0  2020-12-07 07:00:00+00:00                    6590.0
# 1  2020-12-07 07:00:00+00:00                    5582.5
# 2  2020-12-07 07:00:02+00:00                    5684.0
# 3  2020-12-07 07:00:03+00:00                    6031.0
# 4  2020-12-07 07:00:06+00:00                    5140.0
#
#                                    winner.cards.list  \
# 0  [26000036, 26000043, 26000044, 26000050, 26000...
# 1  [26000012, 26000017, 26000022, 26000024, 26000...
# 2  [26000004, 26000036, 26000042, 26000046, 26000...
# 3  [26000004, 26000006, 26000007, 26000011, 26000...
# 4  [26000004, 26000011, 26000013, 26000022, 26000...
#
#                                     loser.cards.list
# 0  [26000000, 26000026, 26000030, 26000041, 27000...
# 1  [26000000, 26000003, 26000007, 26000011, 26000...
# 2  [26000011, 26000026, 26000030, 26000041, 27000...
# 3  [26000032, 26000040, 26000041, 26000049, 26000...
# 4  [26000012, 26000024, 26000045, 26000056, 26000...

# %% [markdown]
# Save the new dataset

# %%
df0 = pd.read_csv("Cards0")
df1 = pd.read_csv("Cards1")
df2 = pd.read_csv("Cards2")
df3 = pd.read_csv("Cards3")
df4 = pd.read_csv("Cards4")

# %%
df0 = df0.rename(columns={'count':'count_0'})
df0['count_1'] = df1['count']
df0['count_2'] = df2['count']
df0['count_3'] = df3['count']
df0['count_4'] = df4['count']

# %%
df0['overall_count'] = df0['count_0'] + df0['count_1'] + df0['count_2'] + df0['count_3'] + df0['count_4']
df0
# Out:
#      team.card1.id   team.card1.name card_type  elixir  rarity  count_0  \
# 0         26000000            Knight     troop       3  Common  24614.0
# 1         26000001           Archers     troop       3  Common   8373.0
# 2         26000002           Goblins     troop       2  Common   1511.0
# 3         26000003             Giant     troop       5    Rare   5000.0
# 4         26000004         P.E.K.K.A     troop       7    Epic  22460.0
# ..             ...               ...       ...     ...     ...      ...
# 97        28000014        Earthquake     spell       3    Rare   1499.0
# 98        28000015  Barbarian Barrel     spell       2    Epic  10870.0
# 99        28000016       Heal Spirit     spell       1    Rare   2096.0
# 100       28000017    Giant Snowball     spell       2  Common   3004.0
# 101       28000018    Royal Delivery     spell       3  Common   1098.0
#
#      count_1  count_2  count_3  count_4  overall_count
# 0    90222.0  95205.0  79899.0  64519.0       354459.0
# 1    29171.0  38557.0  23334.0  13438.0       112873.0
# 2     4028.0   6113.0   5567.0   3905.0        21124.0
# 3    18537.0  41360.0  24764.0  15268.0       104929.0
# 4    56020.0  68813.0  56357.0  27577.0       231227.0
# ..       ...      ...      ...      ...            ...
# 97    4847.0   8091.0  14746.0  15786.0        44969.0
# 98   26882.0  29239.0  55042.0  67916.0       189949.0
# 99    5696.0   4380.0   4937.0   4858.0        21967.0
# 100   8997.0   8636.0  14427.0  20719.0        55783.0
# 101   4192.0   4500.0   4507.0   5105.0        19402.0
#
# [102 rows x 11 columns]

# %%
df0.to_csv("CardList.csv", index=False)

# %%
df = pd.read_csv("BattlesStaging_with_card_features.csv")
card = pd.read_csv("CardMasterListSeason18_12082020_with_elixir_and_rarity.csv")

# %%
trop = [3800, 4200, 4600, 5000, 5500]
for k in range(5):
    arena = df[df['average.startingTrophies'] >= trop[k]]
    if k < 4:
        arena = arena[arena['average.startingTrophies'] < trop[k+1]]
    card[f'count_win_{k}'] = 0
    card[f'count_{k}'] = 0
    for s in ['winner', 'loser']:
        for i in range(1, 9):
            grouped = arena[f'{s}_card_{i}_name'].value_counts().to_frame().reset_index()
            merged = card.merge(grouped, how='outer', left_on='team.card1.name', right_on=f'{s}_card_{i}_name').fillna(0).sort_values('team.card1.id').reset_index()
            new_count = merged[f'count_{k}'] + merged['count']
            card[f'count_{k}'] = new_count
            if s == 'winner':
                new_win_count = merged[f'count_win_{k}'] + merged['count']
                card[f'count_win_{k}'] = new_win_count
    card[f'rwin_{k}'] = card[f'count_win_{k}'] / card[f'count_{k}']

# %%
card = card.drop(columns=['team.card1.id']).rename(columns={'team.card1.name':'card_name'})
card
# Out:
#             card_name card_type  elixir  rarity  count_win_0  count_0  \
# 0              Knight     troop       3  Common      24548.0  48070.0
# 1             Archers     troop       3  Common       8359.0  17039.0
# 2             Goblins     troop       2  Common       1508.0   3226.0
# 3               Giant     troop       5    Rare       4983.0  10354.0
# 4           P.E.K.K.A     troop       7    Epic      22413.0  44613.0
# ..                ...       ...     ...     ...          ...      ...
# 97         Earthquake     spell       3    Rare       1495.0   3339.0
# 98   Barbarian Barrel     spell       2    Epic      10841.0  21600.0
# 99        Heal Spirit     spell       1    Rare       2088.0   4623.0
# 100    Giant Snowball     spell       2  Common       3000.0   6280.0
# 101    Royal Delivery     spell       3  Common       1097.0   2316.0
#
#        rwin_0  count_win_1   count_1    rwin_1  count_win_2   count_2  \
# 0    0.510672      90172.0  177388.0  0.508332      95227.0  190610.0
# 1    0.490580      29160.0   56648.0  0.514758      38537.0   77036.0
# 2    0.467452       4025.0    8158.0  0.493381       6111.0   12043.0
# 3    0.481263      18516.0   35509.0  0.521445      41362.0   81148.0
# 4    0.502387      56014.0  109720.0  0.510518      68783.0  135373.0
# ..        ...          ...       ...       ...          ...       ...
# 97   0.447739       4842.0   10516.0  0.460441       8084.0   16291.0
# 98   0.501898      26875.0   55266.0  0.486285      29235.0   57766.0
# 99   0.451655       5694.0   12574.0  0.452839       4381.0    9492.0
# 100  0.477707       8985.0   18618.0  0.482597       8644.0   17532.0
# 101  0.473661       4183.0    8374.0  0.499522       4506.0    9317.0
#
#        rwin_2  count_win_3   count_3    rwin_3  count_win_4   count_4  \
# 0    0.499591      79921.0  158941.0  0.502834      64596.0  129233.0
# 1    0.500247      23365.0   47299.0  0.493985      13456.0   27592.0
# 2    0.507432       5570.0   11128.0  0.500539       3910.0    7835.0
# 3    0.509711      24781.0   50071.0  0.494917      15289.0   30314.0
# 4    0.508100      56412.0  112128.0  0.503104      27615.0   55301.0
# ..        ...          ...       ...       ...          ...       ...
# 97   0.496225      14743.0   29563.0  0.498698      15805.0   31973.0
# 98   0.506094      55025.0  105199.0  0.523056      67976.0  133582.0
# 99   0.461547       4941.0   10330.0  0.478316       4863.0    9979.0
# 100  0.493041      14410.0   28460.0  0.506325      20745.0   41617.0
# 101  0.483632       4511.0    8935.0  0.504868       5107.0   10153.0
#
#        rwin_4
# 0    0.499841
# 1    0.487678
# 2    0.499043
# 3    0.504354
# 4    0.499358
# ..        ...
# 97   0.494323
# 98   0.508871
# 99   0.487323
# 100  0.498474
# 101  0.503004
#
# [102 rows x 19 columns]

# %%
card.to_csv("CardList.csv", index=False)
